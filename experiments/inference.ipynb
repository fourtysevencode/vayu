# %%
# %pip install ultralytics
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO
from matplotlib import pyplot as plt
import cv2

# %%
model = YOLO(r"C:\Users\HP\OneDrive\Documents\projects\vayu\model\vayu_v1\weights\best.onnx", task = "detect")
results = model(r"C:\Users\HP\OneDrive\Documents\projects\vayu\experiments\test_images\test_img1.jpg")

img = results[0]
img = cv2.cvtColor(img.plot(), cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.axis(False)
plt.title("Prediction")
# Out:
# Loading C:\Users\HP\OneDrive\Documents\projects\vayu\model\vayu_v1\weights\best.onnx for ONNX Runtime inference...
# Using ONNX Runtime 1.24.4 with CPUExecutionProvider
#
# image 1/1 C:\Users\HP\OneDrive\Documents\projects\vayu\experiments\test_images\test_img1.jpg: 640x640 1 smoke, 261.4ms
# Speed: 8.0ms preprocess, 261.4ms inference, 11.5ms postprocess per image at shape (1, 3, 640, 640)
# Text(0.5, 1.0, 'Prediction')
