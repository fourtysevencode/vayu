# %%
import os
from dotenv import load_dotenv
ROBOFLOW_KEY = os.environ["ROBOFLOW_KEY"]

# %%
# %pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key=ROBOFLOW_KEY)
project = rf.workspace("vayu-db").project("vayu-pollution-source-identifier-tnzjh")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.5/169.5 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 17.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 66.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 93.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.13.0.92
#     Uninstalling opencv-python-headless-4.13.0.92:
#       Successfully uninstalled opencv-python-headless-4.13.0.92
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Vayu-Pollution-Source-Identifier-1 in yolov8:: 100%|██████████| 104858/104858 [00:20<00:00, 5212.74it/s]

# %%
# %pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 25.4 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model = YOLO("yolov8n.pt")
model.train(data="/content/Vayu-Pollution-Source-Identifier-1/data.yaml", epochs=25, imgsz=640, batch=16, name="vayu_v1") # 640x640
# Out:
# ...
# Ultralytics 8.4.37 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# Ran out of compute, saving best model into onnx

# %%
from ultralytics import YOLO
model = YOLO("/content/drive/MyDrive/Vayu/model/runs/detect/vayu_v1/weights/best.pt")
model.export(format="onnx")
# Out:
# Ultralytics 8.4.37 🚀 Python-3.12.13 torch-2.10.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# Model summary (fused): 73 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
#
# PyTorch: starting from '/content/drive/MyDrive/Vayu/model/runs/detect/vayu_v1/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 8, 8400) (17.5 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0,<2.0.0', 'onnxslim>=0.1.71', 'onnxruntime'] not found, attempting AutoUpdate...
# Using Python 3.12.13 environment at: /usr
# Resolved 12 packages in 448ms
# Prepared 4 packages in 1.90s
# Installed 4 packages in 564ms
#  + colorama==0.4.6
#  + onnx==1.21.0
#  + onnxruntime==1.24.4
#  + onnxslim==0.1.90
#
# requirements: AutoUpdate success ✅ 3.7s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# ...
